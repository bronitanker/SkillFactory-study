# %% [markdown]
# <a href="https://colab.research.google.com/github/bronitanker/SkillFactory-study/blob/main/%D0%9F%D1%80%D0%BE%D0%B4%D0%B2%D0%B8%D0%BD%D1%83%D1%82%D0%B0%D1%8F_%D1%84%D0%B8%D0%BB%D1%8C%D1%82%D1%80%D0%B0%D1%86%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Продвинутая фильтрация

# %% [markdown]
# ### Подгрузка датасета

# %%
# !gdown --id 18yofdxO2BYBmlw8wmVHEwGFiALR2F4lC 
import pandas as pd
dataset = pd.read_csv('housing_market_dataset.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=18yofdxO2BYBmlw8wmVHEwGFiALR2F4lC
# To: /content/housing_market_dataset.csv
# 100% 29.3M/29.3M [00:00<00:00, 258MB/s]

# %% [markdown]
# ### Как работает фильтр?

# %%
filter = dataset['Год постройки']>2010

# %%
filter
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 12996     True
# 12997     True
# 12998     True
# 12999     True
# 13000     True
# Name: Год постройки, Length: 13001, dtype: bool

# %%
filtred_dataset = dataset[filter]

# %%
filtred_dataset.head()
# Out:
#                                                  url  \
# 1  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 2  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 3  https://move.ru/objects/prodaetsya_2-komn_kvar...
# 4  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 5  https://move.ru/objects/prodaetsya_3-komn_kvar...
#
#                                            Заголовок  \
# 1  Продам 2-комнатную квартиру, 83.2 м², Москва, ...
# 2  Продаю 2-комнатную квартиру, 89.6 м², Москва, ...
# 3  Продам 2-комнатную квартиру, 55.8 м², Москва, ...
# 4  Продаю 3-комнатную квартиру, 128 м², Москва, Д...
# 5  Продам 3-комнатную квартиру, 126.7 м², Москва,...
#
#                                          Новостройка Этап строительства  \
# 1         ЖК City Park («Сити Парк»), м. Выставочная            Отделка
# 2  ЖК Silver (ЖК «Резиденции кинематографистов»),...            Отделка
# 3     Новостройка «Некрасовка-Парк», 5 кв-л, корп. 1               Сдан
# ...

# %% [markdown]
# ### Кейс 1. Необходимо отобрать все квартиры в датасете в домах на Тагильской улице

# %%
dataset['Адрес']
# Out:
# 0               г. Москва\nГольяново\nул Байкальская\n44К3
# 1            г. Москва\nПресненский\nМантулинская улица\n7
# 2        г. Москва\nСвиблово\nпроезд Серебрякова\n11к2 ...
# 3             г. Москва\nВыхино-Жулебино\nул Недорубова\n1
# 4          г. Москва\nТимирязевский\nДмитровское шоссе\n13
#                                ...
# 12996                     Москва, Коммунарка п, участок 18
# 12997                     Москва, Коммунарка п, участок 18
# 12998                     Москва, Коммунарка п, участок 18
# 12999                     Москва, Коммунарка п, участок 18
# 13000                     Москва, Коммунарка п, участок 18
# Name: Адрес, Length: 13001, dtype: object

# %%
street = 'Тагильская'
address = 'Тагильская улица 94'
street in address
# Out:
# True

# %%
address = 'Улица Мира 39'
street in address
# Out:
# False

# %%
def is_address_correct(address):
  return 'Тагильская' in address

# %%
filter = dataset['Адрес'].apply(is_address_correct)
filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12996    False
# 12997    False
# 12998    False
# 12999    False
# 13000    False
# Name: Адрес, Length: 13001, dtype: bool

# %%
filtred_dataset = dataset[filter]
filtred_dataset
# Out:
#                                                      url  \
# 103    https://move.ru/objects/prodaetsya_1-komn_kvar...
# 104    https://move.ru/objects/prodaetsya_3-komn_kvar...
# 207    https://move.ru/objects/prodaetsya_3-komn_kvar...
# 310    https://move.ru/objects/prodaetsya_2-komn_kvar...
# 311    https://move.ru/objects/prodaetsya_2-komn_kvar...
# ...                                                  ...
# 11592  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 11593  https://move.ru/objects/prodaetsya_1-komn_kvar...
# 11799  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 11902  https://move.ru/objects/prodaetsya_3-komn_kvar...
# 12827  https://move.ru/objects/prodaetsya_1-komn_kvar...
#
#                                                Заголовок  \
# 103    Продаю 1-комнатную квартиру, 39.4 м², Москва, ...
# 104    Продается 3-комнатная квартира, 78.2 м², Москв...
# 207    Продам 3-комнатную квартиру, 78.2 м², Москва, ...
# ...

# %%
filtred_dataset['Адрес']
# Out:
# 103      г. Москва\nТагильская улица\n4
# 104      г. Москва\nТагильская улица\n4
# 207      г. Москва\nТагильская улица\n4
# 310      г. Москва\nТагильская улица\n4
# 311      г. Москва\nТагильская улица\n4
#                       ...
# 11592    г. Москва\nТагильская улица\n4
# 11593    г. Москва\nТагильская улица\n4
# 11799    г. Москва\nТагильская улица\n4
# 11902    г. Москва\nТагильская улица\n4
# 12827    г. Москва\nТагильская улица\n4
# Name: Адрес, Length: 149, dtype: object

# %% [markdown]
# ### Кейс 2. Отфильтровать только числовые колонки в датасете для создания большой визуализации по всем числовым колонкам

# %%
dtypes = dataset.dtypes # типы данных колонок датасета
dtypes
# Out:
# url                               object
# Заголовок                         object
# Новостройка                       object
# Этап строительства                object
# Год постройки                    float64
# Класс жилья                       object
# МЦК                               object
# Кол-во просмотров                  int64
# Кол-во просмотров сегодня        float64
# Описание                          object
# Информация                        object
# Адрес                             object
# Тип здания                        object
# Количество этажей                float64
# Цена                              object
# цена за м²                        object
# Комиссия агенту                   object
# Количество комнат                  int64
# Этажность                          int64
# Тип объекта                       object
# Тип объявления                    object
# Общая площадь                     object
# Дата публикации                   object
# ...

# %%
num_dtypes = dtypes[dtypes!='object']
num_dtypes
# Out:
# Год постройки                float64
# Кол-во просмотров              int64
# Кол-во просмотров сегодня    float64
# Количество этажей            float64
# Количество комнат              int64
# Этажность                      int64
# Номер этажа                    int64
# dtype: object

# %%
new_columns = num_dtypes.index

# %%
new_columns
# Out:
# Index(['Год постройки', 'Кол-во просмотров', 'Кол-во просмотров сегодня',
#        'Количество этажей', 'Количество комнат', 'Этажность', 'Номер этажа'],
#       dtype='object')

# %%
filtred_dataset = dataset[num_dtypes.index]
filtred_dataset
# Out:
#        Год постройки  Кол-во просмотров  Кол-во просмотров сегодня  \
# 0             1967.0                125                        3.0
# 1             2020.0                202                        1.0
# 2             2018.0                 20                        1.0
# 3             2019.0                 15                        1.0
# 4             2017.0                 42                        3.0
# ...              ...                ...                        ...
# 12996         2019.0                 50                        1.0
# 12997         2019.0                 48                        1.0
# 12998         2019.0                 60                        1.0
# 12999         2019.0                 50                        1.0
# 13000         2019.0                 47                        1.0
#
#        Количество этажей  Количество комнат  Этажность  Номер этажа
# 0                    5.0                  1          5            3
# ...

# %% [markdown]
# ### Шаблоны продвинутой фильтрации

# %%
# Нестандартная фильтрация с помощью дополнительный функции
def is_address_correct(address):
  return 'Тагильская' in address

mask = dataset['Адрес'].apply(is_address_correct)
filtred_dataset = dataset[mask]

# %%
# Шаблон фильтрации числовых колонок
dtypes = dataset.dtypes
num_dtypes = dtypes[dtypes!='object']
new_columns = num_dtypes.index
filtred_dataset = dataset[num_dtypes.index]
